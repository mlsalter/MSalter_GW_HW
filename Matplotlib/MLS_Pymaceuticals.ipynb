# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "Resources/mouse_drug_data.csv"
clinical_trial_data_to_load = "Resources/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_data_df = pd.read_csv(mouse_drug_data_to_load)
clinical_trial_data_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset (use Mouse Id as it is the common variable btw the 2 sets)
clinical_trial_df = pd.merge(clinical_trial_data_df, mouse_drug_data_df, on="Mouse ID")

# Display the data table for preview
clinical_trial_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites       Drug
# 0     b128          0           45.000000                 0  Capomulin
# 1     b128          5           45.651331                 0  Capomulin
# 2     b128         10           43.270852                 0  Capomulin
# 3     b128         15           43.784893                 0  Capomulin
# 4     b128         20           42.731552                 0  Capomulin

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
#grouping this way it will not take the mean of what you are grouping by it will just take the mean of the other "items"
#["Tumor Vol"] to only receive the mean for these items
tumor_vol_groupby = clinical_trial_df.groupby(["Drug", "Timepoint"]).mean()["Tumor Volume (mm3)"]
#print(clinical_trial_groupby)

# Convert to DataFrame
drug_time_vol_df = pd.DataFrame(tumor_vol_groupby).reset_index() 

# Preview DataFrame
drug_time_vol_df.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0           45.000000
# 1  Capomulin          5           44.266086
# 2  Capomulin         10           43.084291
# 3  Capomulin         15           42.064317
# 4  Capomulin         20           40.716325

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
tumor_vol_sem = clinical_trial_df.groupby(["Drug", "Timepoint"]).sem()["Tumor Volume (mm3)"]
#print(clinical_trial_groupsem)

# Convert to DataFrame
drug_time_vol_sem = pd.DataFrame(tumor_vol_sem).reset_index()

# Preview DataFrame
drug_time_vol_sem.head()
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Data Frames
dtv_pivot = drug_time_vol_df.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

# Preview that Reformatting worked
dtv_pivot
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
# Minor Data Munging to Re-Format the Data Frames (SEM)
dtv_sem_pivot = drug_time_vol_sem.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

# Preview that Reformatting worked
dtv_sem_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182
# 25         0.577401  0.746991  0.741922   0.602513
# 30         0.746045  0.864906  0.899548   0.800043
# 35         1.084929  0.967433  1.003186   0.881426
# 40         1.564779  1.128445  1.410435   0.998515
# 45         1.888586  1.226805  1.576556   1.003576

# %%
# x = linspace(0,10,15);
# y = sin(x/2);
# err = 0.3*ones(size(y));
# errorbar(x,y,err,'-s','MarkerSize',10,...
#     'MarkerEdgeColor','red','MarkerFaceColor','red')
#only show drugs of interest (Capomulin, Infubinol, Ketapril, and Placebo)
drugs = ["Capomulin", "Infubinol", "Ketapril", "Placebo"]
colors = ["b", "r", "g", "m"]
marker = ["o", "^", "s", "d"]
for drug in drugs:
    dtv_pivot.loc[:, drug].plot(label=drug, marker = marker[drugs.index(drug)], color = colors[drugs.index(drug)], ls="--")

# %%
# Generate the Plot (with Error Bars) for 4 treatments - Capomulin, Infubinol, Ketapril, and Placebo
dtv_plt = dtv_pivot.loc[:,["Capomulin", "Infubinol", "Ketapril", "Placebo"]].plot(marker="o", ls="--")
dtv_plt.title()
dtv_plt.xlabel()
dtv_plt.ylabel()

# Save the Figure
dtv_plt.savefig()

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
#grouping this way it will not take the mean of what you are grouping by it will just take the mean of the other "items"
#["Tumor Vol"] to only receive the mean for these items
metastatic_groupby = clinical_trial_df.groupby(["Drug", "Timepoint"]).mean()["Metastatic Sites"]
#print(clinical_trial_groupby)

# Convert to DataFrame
drug_time_site_df = pd.DataFrame(metastatic_groupby).reset_index() 

# Preview DataFrame
drug_time_site_df.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.160000
# 2  Capomulin         10          0.320000
# 3  Capomulin         15          0.375000
# 4  Capomulin         20          0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
metastatic_sem = clinical_trial_df.groupby(["Drug", "Timepoint"]).sem()["Metastatic Sites"]

# Convert to DataFrame
drug_time_site_sem = pd.DataFrame(metastatic_sem).reset_index()

# Preview DataFrame
drug_time_site_sem.head()
# Out:
#         Drug  Timepoint  Metastatic Sites
# 0  Capomulin          0          0.000000
# 1  Capomulin          5          0.074833
# 2  Capomulin         10          0.125433
# 3  Capomulin         15          0.132048
# 4  Capomulin         20          0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
dts_pivot = drug_time_site_df.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# Preview that Reformatting worked
dts_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118
# 25         1.357143  0.652174  1.157895   1.687500
# 30         1.615385  0.782609  1.388889   1.933333
# 35         2.300000  0.952381  1.562500   2.285714
# 40         2.777778  1.100000  1.583333   2.785714
# 45         2.571429  1.250000  1.727273   3.071429

# %%
# Minor Data Munging to Re-Format the Data Frames (SEM)
dts_sem_pivot = drug_time_site_sem.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# Preview that Reformatting worked
dts_sem_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378
# 25         0.199095  0.119430  0.219824   0.236621
# 30         0.266469  0.139968  0.230641   0.248168
# 35         0.366667  0.145997  0.240983   0.285714
# 40         0.433903  0.160591  0.312815   0.299791
# 45         0.428571  0.190221  0.359062   0.286400

# %%
# Generate the Plot (with Error Bars) for 4 treatments - Capomulin, Infubinol, Ketapril, and Placebo
dtv_plt = dtv_pivot.loc[:,["Capomulin", "Infubinol", "Ketapril", "Placebo"]].plot(marker="^", ls="--")
dtv_plt.title()
dtv_plt.xlabel()
dtv_plt.ylabel()

# Save the Figure
dtv_plt.savefig()

# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
mice_count_grouped = clinical_trial_df.groupby(["Drug", "Timepoint"]).count()["Mouse ID"]
#print(mice_count_grouped)

# Convert to DataFrame
mice_count_df = pd.DataFrame(mice_count_grouped).reset_index()
mice_count_df = mice_count_df.rename(columns={"Mouse ID":"Mouse Count"})

# Preview DataFrame
mice_count_df.head()
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames
mice_count_pivot = mice_count_df.pivot(index="Timepoint", columns="Drug", values="Mouse Count")

# Preview the Data Frame
mice_count_pivot
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17
# 25               14        23        19         16
# 30               13        23        18         15
# 35               10        21        16         14
# 40                9        20        12         14
# 45                7        20        11         14

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
tumor_pct_change = for drug in new - old / old
# Display the data to confirm
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0                NaN  0.000000   0.000000  0.000000  0.000000  0.000000
# 5                NaN  0.050534   0.012020  0.006952 -0.012515  0.007041
# 10               NaN  0.120713   0.023170  0.003610 -0.017911  0.014973
# 15               NaN  0.190892   0.024002  0.021514 -0.027995  0.008378
# 20               NaN  0.280986   0.019952  0.032393 -0.023249  0.013428
# 25               NaN  0.359247   0.026297  0.035246 -0.016419  0.013231
# 30               NaN  0.464289   0.026949  0.046229 -0.023527  0.004190
# 35               NaN  0.555591   0.032551  0.043285 -0.010834 -0.004219
# 40               NaN  0.663182   0.027574  0.046004 -0.007081 -0.008355
# 45               NaN  0.769848   0.025309  0.074631 -0.019776 -0.017056
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.002618 -0.069930  0.081525  -0.014216
# 10        -0.006511 -0.133796  0.162981  -0.015647
# 15        -0.005694 -0.187444  0.241820  -0.014562
# 20        -0.018720 -0.245721  0.343679  -0.016592
# 25        -0.034418 -0.297813  0.441107  -0.013054
# 30        -0.026964 -0.334956  0.545785  -0.035322
# 35        -0.033169 -0.379422  0.667220  -0.037657
# 40        -0.030854 -0.419878  0.786959  -0.037329
# 45        -0.026813 -0.472436  0.957864  -0.036199

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
